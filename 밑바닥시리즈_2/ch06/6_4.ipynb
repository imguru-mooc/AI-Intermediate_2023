# %% [markdown]
# ### LSTM을 사용한 언어 모델

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %% [markdown]
# ### 학습을 위한 코드

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9997.00
# | 에폭 1 |  반복 21 / 1327 | 시간 3[s] | 퍼플렉서티 2920.36
# | 에폭 1 |  반복 41 / 1327 | 시간 6[s] | 퍼플렉서티 1272.70
# | 에폭 1 |  반복 61 / 1327 | 시간 9[s] | 퍼플렉서티 966.96
# | 에폭 1 |  반복 81 / 1327 | 시간 12[s] | 퍼플렉서티 778.01
# | 에폭 1 |  반복 101 / 1327 | 시간 16[s] | 퍼플렉서티 648.65
# | 에폭 1 |  반복 121 / 1327 | 시간 19[s] | 퍼플렉서티 621.44
# | 에폭 1 |  반복 141 / 1327 | 시간 22[s] | 퍼플렉서티 605.79
# | 에폭 1 |  반복 161 / 1327 | 시간 25[s] | 퍼플렉서티 574.12
# | 에폭 1 |  반복 181 / 1327 | 시간 29[s] | 퍼플렉서티 586.41
# | 에폭 1 |  반복 201 / 1327 | 시간 32[s] | 퍼플렉서티 501.98
# | 에폭 1 |  반복 221 / 1327 | 시간 35[s] | 퍼플렉서티 479.10
# | 에폭 1 |  반복 241 / 1327 | 시간 39[s] | 퍼플렉서티 442.76
# | 에폭 1 |  반복 261 / 1327 | 시간 42[s] | 퍼플렉서티 468.44
# | 에폭 1 |  반복 281 / 1327 | 시간 45[s] | 퍼플렉서티 453.36
# | 에폭 1 |  반복 301 / 1327 | 시간 48[s] | 퍼플렉서티 390.82
# | 에폭 1 |  반복 321 / 1327 | 시간 52[s] | 퍼플렉서티 347.38
# | 에폭 1 |  반복 341 / 1327 | 시간 55[s] | 퍼플렉서티 404.97
# | 에폭 1 |  반복 361 / 1327 | 시간 58[s] | 퍼플렉서티 411.31
# | 에폭 1 |  반복 381 / 1327 | 시간 61[s] | 퍼플렉서티 334.87
# | 에폭 1 |  반복 401 / 1327 | 시간 65[s] | 퍼플렉서티 348.44
# | 에폭 1 |  반복 421 / 1327 | 시간 68[s] | 퍼플렉서티 347.83
# | 에폭 1 |  반복 441 / 1327 | 시간 71[s] | 퍼플렉서티 328.60
# | 에폭 1 |  반복 461 / 1327 | 시간 74[s] | 퍼플렉서티 323.66
# | 에폭 1 |  반복 481 / 1327 | 시간 78[s] | 퍼플렉서티 302.95
# | 에폭 1 |  반복 501 / 1327 | 시간 81[s] | 퍼플렉서티 309.68
# | 에폭 1 |  반복 521 / 1327 | 시간 84[s] | 퍼플렉서티 304.27
# | 에폭 1 |  반복 541 / 1327 | 시간 87[s] | 퍼플렉서티 316.40
# | 에폭 1 |  반복 561 / 1327 | 시간 90[s] | 퍼플렉서티 280.56
# | 에폭 1 |  반복 581 / 1327 | 시간 94[s] | 퍼플렉서티 255.78
# | 에폭 1 |  반복 601 / 1327 | 시간 97[s] | 퍼플렉서티 335.71
# | 에폭 1 |  반복 621 / 1327 | 시간 100[s] | 퍼플렉서티 310.22
# | 에폭 1 |  반복 641 / 1327 | 시간 103[s] | 퍼플렉서티 275.77
# | 에폭 1 |  반복 661 / 1327 | 시간 107[s] | 퍼플렉서티 269.00
# | 에폭 1 |  반복 681 / 1327 | 시간 110[s] | 퍼플렉서티 227.60
# | 에폭 1 |  반복 701 / 1327 | 시간 113[s] | 퍼플렉서티 247.41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 32>()
#      29 trainer = RnnlmTrainer(model, optimizer)
#      31 # 기울기 클리핑을 적용하여 학습
# ---> 32 trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
#      33             eval_interval=20)
#      34 trainer.plot(ylim=(0, 500))
#      36 # 테스트 데이터로 평가
#
# File D:\올인원과정\밑바닥시리즈_2\ch06\..\common\trainer.py:113, in RnnlmTrainer.fit(self, xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval)
#     111 # 기울기를 구해 매개변수 갱신
#     112 loss = model.forward(batch_x, batch_t)
# --> 113 model.backward()
#     114 params, grads = remove_duplicate(model.params, model.grads)  # 공유된 가중치를 하나로 모음
#     115 if max_grad is not None:
#
# File D:\올인원과정\밑바닥시리즈_2\ch06\rnnlm.py:49, in Rnnlm.backward(self, dout)
#      47 dout = self.loss_layer.backward(dout)
#      48 for layer in reversed(self.layers):
# ---> 49     dout = layer.backward(dout)
#      50 return dout
#
# File D:\올인원과정\밑바닥시리즈_2\ch06\..\common\time_layers.py:256, in TimeEmbedding.backward(self, dout)
#     254     layer = self.layers[t]
#     255     layer.backward(dout[:, t, :])
# --> 256     grad += layer.grads[0]
#     258 self.grads[0][...] = grad
#     259 return None
#
# KeyboardInterrupt:
